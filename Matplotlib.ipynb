# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 7.6/7.6 MB 1.3 MB/s eta 0:00:00
# ...
#      ------------------------------------ 163.0/163.0 kB 264.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 831.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.4/55.4 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 894.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB 1.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from matplotlib import pyplot as plt
x=[5,10,20,15,25]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
#subplot--->small grpahs

y1=[10,15,25,20,40]
y2=[-5,10,5,6,15]

plt.suptitle("Data")

plt.subplot(2,2,1)
plt.title("Graph-1")
plt.plot(x,y)

plt.subplot(2,2,2)
plt.title("Graph-2")
plt.plot(x,y1)

plt.subplot(2,2,3)
plt.title("Graph-3")
plt.plot(x,y2)

plt.subplot(2,2,4)
plt.title("Graph-4")
plt.plot(y1,y2)

plt.show()
